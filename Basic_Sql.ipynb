# %% [markdown]
#  1.create a new database named company_db and create h table named employees with the following columns.
#
# Solution-
# create database company_db;
# use company_db;
# create table employees(
#   employee_id int PRIMARY KEY,
#   first_name VARCHAR(50),
#   last_name VARCHAR(50),
#   department_name VARCHAR(50),
#   salary INT,
#   hire_date DATE);
#
# select * from employees;
#
# 2.insert data into employee table
# insert into employees
#   values
#   (101,"Amit","Sharma","HR",50000,"2020-01-15"),
#   (102,"Riya","kapoor","Sales",75000,"2019-03-22"),
#   (103,"Raj","mehta","IT",90000,"2018-11-07"),
#   (104,"Neha","verma","IT",85000,"2021-09-01"),
#   (105,"Arjun","singh","Finance",60000,"2022-02-10");
#
# 3.Display all employee record sorted by salary (lowest to highest)
#   select * from employee
#   order by salary asc;
#
# 4.Show Employees Sorted by Department (A-Z) and Salary (High → Low)
#   select * from employee
#   where department asc AND salary desc;
#
# 5.List All Employees in the IT Department, Ordered by Hire Date (Newest First)
# select * from employees where Department="IT" AND Hire date="01-01-2026";
#
# 6.create and populate a sales table.
# solution-
# create table sales(
#    sale_id INT,
#    customer_name VARCHAR(50),
#    amount INT,
#    sale_date DATE
#
# );
#
# insert into sales values
# (1,"Aditi",1500,"2024-08-01"),
# (2,"Rohan",2200,"2024-08-03"),
# (3,"Aditi",3500,"2024-09-05"),
# (4,"Meena",2700,"2024-09-15),
# (5,"Rohan",4500,"2024-09-25");
#
# 7.Display all sales records sorted by amount(Highest->Lowest)
# solution-
# select * from sales order by amount desc;
#
# 8.show all sales made by customer"Aditi".
# solution-
# select * from sales where customer_name ="Adidti";
#
# 9.what is the difference between a Primary key and Foreign key.
# solution-
# Primary Key-primary key is a uniquely identifier it can not contain null values.
# Foreign key-foreign key present in child table and they are act primary key in parent table.it can contain  null values.
#
# 10.what are constraints in sql and why are they used.
# solution-
# constraints are rules applied to table column and constraints limit the the data that can be inserted,updated and deleted.commom type of constraints is  primary,not null,foreign key,uniques etc.
